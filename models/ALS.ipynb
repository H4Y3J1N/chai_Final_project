# %% [markdown]
# ## MovieLens 데이터셋을 이용한 Collaborative Filtering 연습

# %% [markdown]
# ## Collaborative Filtering Open-source Libraries
#
# 1. implicit : https://github.com/benfred/implicit
#
# 2. Surprise : https://github.com/NicolasHug/Surprise
#
# -----
# 3. LightFM : https://github.com/lyst/lightfm
#
# 4. Spotlight : https://github.com/maciejkula/spotlight (pytorch)
#
# 5. Buffalo : https://github.com/kakao/buffalo  (Win10에서 설치 안됨)

# %% [markdown]
# ### 1. Implicit

# %% [markdown]
# - Item-based CF https://github.com/benfred/implicit/blob/master/implicit/nearest_neighbours.py

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install implicit
# Out:
# Collecting implicit
#   Downloading implicit-0.4.8.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from implicit) (4.62.3)
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.7/dist-packages (from implicit) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from implicit) (1.19.5)
# Building wheels for collected packages: implicit
#   Building wheel for implicit (PEP 517) ... done
#   Created wheel for implicit: filename=implicit-0.4.8-cp37-cp37m-linux_x86_64.whl size=4606579 sha256=603247c092d2875f9c7373fe52d4f905919f81a9d08eee4807fb854a88ae551a
#   Stored in directory: /root/.cache/pip/wheels/88/e6/34/25e73cccbaf1a961154bb562a5f86123b68fdbf40e306073d6
# Successfully built implicit
# Installing collected packages: implicit
# Successfully installed implicit-0.4.8

# %%
import numpy as np
from time import time
from tqdm import tqdm_notebook
import implicit

from implicit.nearest_neighbours import CosineRecommender
from implicit.datasets.movielens import get_movielens

titles, ratings = get_movielens("100k")
# Out:
# 0.00B [00:00, ?B/s]

# %%
ratings.toarray().shape
# Out:
# (1683, 944)

# %%
titles
# Out:
# array([b'', b'Toy Story (1995)', b'GoldenEye (1995)', ...,
#        b'Sliding Doors (1998)', b'You So Crazy (1994)',
#        b'Scream of Stone (Schrei aus Stein) (1991)'], dtype=object)

# %%
ratings
# Out:
# <1683x944 sparse matrix of type '<class 'numpy.float32'>'
# 	with 100000 stored elements in Compressed Sparse Row format>

# %%
# implicit의 CosineRecommender모델
model = CosineRecommender()
start_t = time()
model.fit(ratings)
end_t = time()
print("Elapsed Time for CF : %.3fsec" % (end_t - start_t))
# Out:
#   0%|          | 0/1683 [00:00<?, ?it/s]
# Elapsed Time for CF : 0.192sec

# %%
user_items = ratings.T.tocsr() # .T

# %%
model.recommend(1, user_items)
# Out:
# [(423, 120.23832527080934),
#  (385, 75.83986249299838),
#  (403, 69.91658430995363),
#  (568, 57.16350758378815),
#  (405, 56.051047115754045),
#  (474, 44.25502688952575),
#  (393, 42.65925502490433),
#  (357, 41.67387639963299),
#  (550, 39.8505997586499),
#  (318, 38.622309611229106)]

# %%
#
for xi in range(10):
    recommendations = model.recommend(xi, user_items)
    print(recommendations)
# Out:
# []
# [(423, 120.23832527080934), (385, 75.83986249299838), (403, 69.91658430995363), (568, 57.16350758378815), (405, 56.051047115754045), (474, 44.25502688952575), (393, 42.65925502490433), (357, 41.67387639963299), (550, 39.8505997586499), (318, 38.622309611229106)]
# [(121, 40.225367066630014), (117, 39.29225874430751), (181, 35.68579095309081), (7, 29.68970226641666), (405, 29.361682795225203), (742, 22.891083166822884), (328, 21.00804009048448), (118, 20.30540230794754), (546, 20.09678616983666), (347, 20.060081658847135)]
# [(313, 28.68715943980728), (286, 17.723778908110333), (748, 15.203835211489709), (879, 14.950572215973814), (678, 14.083828353493598), (269, 13.449728706253074), (315, 13.361294557864941), (301, 10.656446304592563), (316, 10.604457263734151), (895, 10.537210220642704)]
# [(313, 18.048566260402367), (302, 17.55588572442778), (333, 17.518365289014476), (748, 15.372360308008071), (286, 14.206705726612451), (181, 13.898964689572573), (7, 13.25499305832247), (307, 12.480327819569071), (56, 12.23442746279491), (174, 11.208028053401195)]
# [(195, 84.21963169631275), (82, 81.4343227456816), (56, 66.46496904610645), (96, 54.61214866633196), (202, 47.385119575868295), (161, 41.49790923074377), (238, 39.122585391560186), (7, 36.37325506444334), (550, 36.103311535360476), (568, 33.29813506424923)]
# [(172, 105.3288762981285), (210, 70.58022102583604), (654, 54.17310018749071), (603, 52.04124008885641), (196, 48.06218443279027), (181, 45.964492290572245), (176, 44.32467591099803), (96, 43.618326134797705), (97, 41.86669802164624), (82, 39.27250240431304)]
# [(117, 55.48629154677449), (95, 52.47069275762663), (218, 49.88982995150582), (1, 49.3504464151376), (209, 46.31665050842104), (94, 41.716088227329834), (88, 39.83287962206163), (222, 34.13403928452977), (2, 33.95842922202057), (742, 33.413753809599925)]
# [(204, 63.087720250784436), (98, 47.41672493837916), (161, 40.36263344827648), (168, 35.85487292883155), (173, 30.99217748112482), (69, 30.958779310689337), (226, 28.804207497209735), (230, 27.30208036973078), (423, 24.6837031041966), (265, 22.28267522507697)]
# [(174, 16.426058770274185), (98, 14.068167503283725), (181, 13.29309263027568), (121, 12.15032915796429), (100, 11.365337077864218), (134, 11.13213570510262), (204, 10.379144630092057), (197, 10.324003403346206), (1, 10.286948059988205), (168, 9.61875156941775)]

# %%
#  implicit-als
model2 = implicit.als.AlternatingLeastSquares(factors=50)

# %%
model2.fit(ratings)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# recommend items for a user
recommendations = model2.recommend(1, user_items)
print('recommended ',recommendations)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-5d71a8c4b90f> in <module>()
#       1 # recommend items for a user
# ----> 2 recommendations = model2.recommend(1, user_items)
#       3 print('recommended ',recommendations)
#
# /usr/local/lib/python3.7/dist-packages/implicit/gpu/matrix_factorization_base.py in recommend(self, userid, user_items, N, filter_already_liked_items, filter_items, recalculate_user)
#      49         # calculate the top N items, removing the users own liked items from the results
#      50         # TODO: own like filtering (direct in topk class
# ---> 51         ids, scores = self._knn.topk(self.item_factors, self.user_factors[userid], count)
#      52         return list(
#      53             itertools.islice((rec for rec in zip(ids[0], scores[0]) if rec[0] not in liked), N)
#
# implicit/gpu/_cuda.pyx in implicit.gpu._cuda.KnnQuery.topk()
#
# RuntimeError: Cuda Error: invalid device function (implicit/gpu/knn.cu:336)

# %%
# find related items
related = model2.similar_items(1)
print(related)
# Out:
# [(1, 1.0000000000000069), (50, 0.7345720560109757), (181, 0.6999249712920779), (121, 0.6897856040758548), (117, 0.66455478870842), (405, 0.6413217603411484), (151, 0.6381576334869846), (222, 0.6367273145962258), (100, 0.630600760761389), (237, 0.6240747014811365)]

# %% [markdown]
# - Understand `indptr` in csr_matrix

# %% [markdown]
# ![indpt](figs/indptr.png)

# %%
user_count = np.ediff1d(ratings.indptr)
to_generate = sorted(np.arange(len(titles)), key=lambda x: -user_count[x])

# %%
ratings.indptr
# Out:
# array([     0,      0,    452, ...,  99998,  99999, 100000], dtype=int32)

# %%
user_count
# Out:
# array([  0, 452, 131, ...,   1,   1,   1], dtype=int32)

# %%
to_generate
# Out:
# [50,
#  258,
#  100,
#  181,
#  294,
#  286,
#  288,
#  1,
#  300,
#  121,
#  174,
#  127,
#  56,
#  7,
#  98,
#  237,
#  117,
#  172,
#  222,
#  204,
#  313,
#  405,
#  79,
#  210,
#  151,
#  173,
#  69,
#  168,
#  748,
#  269,
#  257,
#  195,
#  423,
#  9,
#  276,
#  318,
#  22,
#  302,
#  96,
#  328,
#  15,
#  25,
#  118,
#  183,
#  216,
#  176,
#  64,
#  202,
#  234,
#  28,
#  191,
#  89,
#  111,
#  275,
#  12,
#  742,
#  357,
#  82,
#  135,
#  289,
#  97,
#  238,
#  268,
#  546,
#  70,
#  186,
#  196,
#  333,
#  475,
#  153,
#  132,
#  125,
#  228,
#  144,
#  483,
#  194,
#  245,
#  323,
#  185,
#  197,
#  11,
#  282,
#  496,
#  301,
#  568,
#  265,
#  655,
#  182,
#  273,
#  143,
#  179,
#  180,
#  471,
#  71,
#  161,
#  8,
#  95,
#  427,
#  678,
#  322,
#  235,
#  435,
#  508,
#  88,
#  215,
#  271,
#  4,
#  187,
#  603,
#  175,
#  385,
#  200,
#  211,
#  597,
#  588,
#  403,
#  515,
#  208,
#  230,
#  134,
#  272,
#  250,
#  527,
#  298,
#  474,
#  284,
#  393,
#  209,
#  274,
#  340,
#  307,
#  124,
#  147,
#  13,
#  14,
#  23,
#  203,
#  514,
#  732,
#  751,
#  479,
#  480,
#  566,
#  419,
#  591,
#  283,
#  83,
#  845,
#  58,
#  326,
#  327,
#  24,
#  154,
#  432,
#  511,
#  99,
#  255,
#  133,
#  137,
#  218,
#  229,
#  433,
#  651,
#  188,
#  367,
#  402,
#  451,
#  321,
#  628,
#  684,
#  319,
#  582,
#  226,
#  199,
#  523,
#  692,
#  739,
#  411,
#  66,
#  259,
#  285,
#  410,
#  443,
#  227,
#  248,
#  315,
#  476,
#  252,
#  472,
#  150,
#  193,
#  685,
#  240,
#  690,
#  31,
#  431,
#  660,
#  498,
#  77,
#  164,
#  550,
#  86,
#  239,
#  55,
#  304,
#  763,
#  42,
#  156,
#  462,
#  1028,
#  293,
#  654,
#  281,
#  310,
#  455,
#  91,
#  332,
#  358,
#  231,
#  87,
#  484,
#  94,
#  177,
#  347,
#  559,
#  705,
#  735,
#  1016,
#  205,
#  223,
#  270,
#  879,
#  68,
#  213,
#  303,
#  1047,
#  47,
#  243,
#  2,
#  657,
#  109,
#  249,
#  72,
#  129,
#  418,
#  531,
#  53,
#  73,
#  148,
#  241,
#  325,
#  482,
#  756,
#  62,
#  157,
#  198,
#  260,
#  291,
#  596,
#  346,
#  473,
#  116,
#  178,
#  324,
#  485,
#  190,
#  233,
#  246,
#  343,
#  520,
#  526,
#  750,
#  501,
#  504,
#  170,
#  428,
#  447,
#  509,
#  510,
#  528,
#  38,
#  217,
#  521,
#  631,
#  746,
#  866,
#  169,
#  48,
#  242,
#  449,
#  184,
#  192,
#  380,
#  663,
#  65,
#  123,
#  659,
#  762,
#  29,
#  214,
#  292,
#  331,
#  93,
#  316,
#  408,
#  815,
#  219,
#  382,
#  81,
#  225,
#  470,
#  679,
#  122,
#  162,
#  421,
#  895,
#  136,
#  54,
#  92,
#  478,
#  709,
#  928,
#  67,
#  317,
#  554,
#  699,
#  747,
#  159,
#  232,
#  264,
#  378,
#  404,
#  708,
#  926,
#  381,
#  665,
#  682,
#  1012,
#  436,
#  155,
#  507,
#  1014,
#  33,
#  126,
#  356,
#  429,
#  290,
#  306,
#  755,
#  919,
#  90,
#  131,
#  477,
#  412,
#  430,
#  529,
#  576,
#  820,
#  1011,
#  17,
#  163,
#  212,
#  549,
#  578,
#  744,
#  52,
#  338,
#  517,
#  636,
#  693,
#  831,
#  3,
#  458,
#  506,
#  652,
#  1039,
#  10,
#  201,
#  399,
#  518,
#  642,
#  661,
#  39,
#  305,
#  386,
#  689,
#  715,
#  5,
#  673,
#  720,
#  792,
#  864,
#  988,
#  280,
#  425,
#  448,
#  465,
#  924,
#  21,
#  781,
#  59,
#  825,
#  63,
#  152,
#  625,
#  640,
#  662,
#  717,
#  823,
#  32,
#  49,
#  51,
#  420,
#  604,
#  729,
#  873,
#  45,
#  312,
#  519,
#  530,
#  826,
#  930,
#  44,
#  584,
#  658,
#  696,
#  710,
#  287,
#  736,
#  295,
#  629,
#  676,
#  1074,
#  401,
#  724,
#  778,
#  311,
#  627,
#  871,
#  969,
#  105,
#  221,
#  461,
#  1101,
#  26,
#  101,
#  299,
#  417,
#  525,
#  1048,
#  20,
#  141,
#  354,
#  513,
#  650,
#  713,
#  106,
#  277,
#  463,
#  544,
#  949,
#  409,
#  558,
#  647,
#  707,
#  19,
#  160,
#  384,
#  633,
#  687,
#  780,
#  80,
#  392,
#  487,
#  497,
#  505,
#  934,
#  1035,
#  114,
#  120,
#  167,
#  371,
#  434,
#  469,
#  491,
#  569,
#  648,
#  189,
#  207,
#  220,
#  262,
#  452,
#  538,
#  606,
#  607,
#  790,
#  855,
#  993,
#  1073,
#  108,
#  128,
#  145,
#  171,
#  345,
#  387,
#  488,
#  672,
#  60,
#  165,
#  334,
#  416,
#  468,
#  486,
#  595,
#  616,
#  619,
#  887,
#  959,
#  1009,
#  450,
#  481,
#  516,
#  553,
#  727,
#  740,
#  254,
#  414,
#  499,
#  1041,
#  140,
#  946,
#  158,
#  278,
#  493,
#  609,
#  939,
#  61,
#  391,
#  492,
#  495,
#  561,
#  581,
#  615,
#  737,
#  880,
#  1119,
#  85,
#  166,
#  632,
#  716,
#  722,
#  741,
#  898,
#  923,
#  27,
#  40,
#  142,
#  502,
#  512,
#  754,
#  770,
#  827,
#  931,
#  395,
#  494,
#  813,
#  344,
#  369,
#  413,
#  847,
#  76,
#  102,
#  396,
#  535,
#  675,
#  721,
#  441,
#  702,
#  840,
#  849,
#  875,
#  886,
#  892,
#  1065,
#  342,
#  466,
#  489,
#  768,
#  877,
#  542,
#  614,
#  712,
#  749,
#  139,
#  206,
#  297,
#  490,
#  570,
#  602,
#  649,
#  686,
#  806,
#  1017,
#  406,
#  541,
#  683,
#  772,
#  824,
#  833,
#  955,
#  977,
#  244,
#  365,
#  456,
#  467,
#  562,
#  674,
#  841,
#  948,
#  1228,
#  339,
#  363,
#  366,
#  789,
#  876,
#  1007,
#  1118,
#  251,
#  444,
#  524,
#  664,
#  671,
#  760,
#  794,
#  921,
#  941,
#  956,
#  1046,
#  1135,
#  236,
#  329,
#  552,
#  728,
#  810,
#  881,
#  942,
#  952,
#  1079,
#  1197,
#  224,
#  539,
#  575,
#  638,
#  656,
#  688,
#  694,
#  761,
#  846,
#  896,
#  975,
#  984,
#  1010,
#  1025,
#  1067,
#  1142,
#  1188,
#  261,
#  336,
#  379,
#  407,
#  540,
#  589,
#  620,
#  809,
#  890,
#  944,
#  1050,
#  1091,
#  107,
#  769,
#  844,
#  872,
#  900,
#  902,
#  1098,
#  330,
#  350,
#  355,
#  547,
#  577,
#  610,
#  771,
#  963,
#  1051,
#  1063,
#  1110,
#  43,
#  57,
#  611,
#  639,
#  697,
#  802,
#  819,
#  929,
#  932,
#  943,
#  945,
#  1044,
#  16,
#  370,
#  373,
#  503,
#  585,
#  622,
#  623,
#  731,
#  743,
#  752,
#  785,
#  874,
#  951,
#  1060,
#  1217,
#  1221,
#  637,
#  646,
#  1013,
#  1021,
#  1089,
#  1134,
#  1210,
#  30,
#  41,
#  364,
#  583,
#  783,
#  937,
#  1008,
#  1090,
#  670,
#  796,
#  856,
#  1244,
#  266,
#  522,
#  567,
#  644,
#  979,
#  1020,
#  1059,
#  372,
#  586,
#  612,
#  653,
#  680,
#  723,
#  829,
#  882,
#  922,
#  925,
#  961,
#  971,
#  78,
#  573,
#  641,
#  878,
#  990,
#  1139,
#  1267,
#  426,
#  580,
#  765,
#  774,
#  936,
#  940,
#  974,
#  989,
#  1018,
#  1022,
#  1033,
#  1126,
#  1132,
#  1226,
#  110,
#  349,
#  368,
#  383,
#  500,
#  605,
#  630,
#  738,
#  779,
#  797,
#  808,
#  995,
#  1019,
#  1023,
#  1194,
#  308,
#  537,
#  608,
#  843,
#  950,
#  1133,
#  1215,
#  1220,
#  563,
#  572,
#  719,
#  764,
#  1061,
#  1095,
#  1115,
#  1136,
#  1137,
#  279,
#  309,
#  362,
#  388,
#  460,
#  571,
#  972,
#  1042,
#  1109,
#  1129,
#  1152,
#  1411,
#  46,
#  348,
#  389,
#  457,
#  464,
#  564,
#  613,
#  645,
#  681,
#  734,
#  805,
#  842,
#  905,
#  978,
#  1034,
#  1070,
#  1170,
#  6,
#  253,
#  352,
#  398,
#  422,
#  775,
#  800,
#  836,
#  966,
#  1149,
#  1160,
#  1218,
#  1240,
#  1284,
#  415,
#  818,
#  834,
#  837,
#  938,
#  960,
#  991,
#  1040,
#  1045,
#  1049,
#  1052,
#  1157,
#  1163,
#  1222,
#  376,
#  459,
#  551,
#  634,
#  704,
#  730,
#  753,
#  863,
#  869,
#  1036,
#  1037,
#  1053,
#  130,
#  149,
#  375,
#  635,
#  962,
#  986,
#  1006,
#  1054,
#  1093,
#  1199,
#  1258,
#  1315,
#  445,
#  532,
#  560,
#  565,
#  624,
#  821,
#  832,
#  953,
#  980,
#  985,
#  1005,
#  1057,
#  1078,
#  1113,
#  1168,
#  1176,
#  1231,
#  335,
#  543,
#  758,
#  795,
#  816,
#  865,
#  906,
#  933,
#  965,
#  1084,
#  1086,
#  1121,
#  1147,
#  1203,
#  112,
#  320,
#  351,
#  601,
#  904,
#  908,
#  982,
#  1030,
#  1208,
#  1219,
#  1296,
#  1407,
#  138,
#  263,
#  424,
#  579,
#  703,
#  894,
#  1103,
#  1117,
#  1153,
#  1178,
#  1183,
#  1206,
#  1245,
#  1248,
#  1265,
#  1277,
#  1283,
#  1444,
#  84,
#  337,
#  359,
#  400,
#  590,
#  617,
#  618,
#  811,
#  812,
#  862,
#  903,
#  916,
#  968,
#  1069,
#  1097,
#  1105,
#  1107,
#  1185,
#  1204,
#  1230,
#  1239,
#  1303,
#  1401,
#  1478,
#  557,
#  773,
#  947,
#  1001,
#  1038,
#  1120,
#  1140,
#  1207,
#  1232,
#  1286,
#  256,
#  453,
#  454,
#  691,
#  718,
#  725,
#  745,
#  801,
#  854,
#  ...]

# %%
with tqdm_notebook(total=len(to_generate)) as progress:
    with open("result.txt", 'w', encoding="utf-8") as f:
        for movieid in to_generate:
            if ratings.indptr[movieid] != ratings.indptr[movieid + 1]:
                title = titles[movieid]
                for other, score in model.similar_items(movieid, 11):
                    print("%s\t%s\t%s\n" % (title, titles[other], score), file=f)
            progress.update(1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """Entry point for launching an IPython kernel.
#   0%|          | 0/1683 [00:00<?, ?it/s]

# %% [markdown]
# ### 2. Surprise

# %% [markdown]
# - Item-based CF
# https://surprise.readthedocs.io/en/stable/knn_inspired.html#surprise.prediction_algorithms.knns.KNNBasic

# %%
from surprise import SVD
from surprise import KNNBasic
from surprise import Dataset
from surprise import accuracy
from surprise.model_selection import train_test_split

# Load the movielens-100k dataset (download it if needed).
data = Dataset.load_builtin('ml-100k')
trainset, testset = train_test_split(data, test_size=.25)


# Train the algorithm on the trainset, and predict ratings for the testset
algo = KNNBasic()
algo.fit(trainset)
predictions = algo.test(testset)

def get_Iu(uid):
    """ return the number of items rated by given user
    args: 
      uid: the id of the user
    returns: 
      the number of items rated by the user
    """
    try:
        return len(trainset.ur[trainset.to_inner_uid(uid)])
    except ValueError: # user was not part of the trainset
        return 0
    
def get_Ui(iid):
    """ return number of users that have rated given item
    args:
      iid: the raw id of the item
    returns:
      the number of users that have rated the item.
    """
    try: 
        return len(trainset.ir[trainset.to_inner_iid(iid)])
    except ValueError:
        return 0


# Then compute RMSE
accuracy.rmse(predictions)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9801
# 0.9800729778583429

# %%
import pandas as pd

df = pd.DataFrame(predictions, columns=['uid', 'iid', 'rui', 'est', 'details'])
df['Iu'] = df.uid.apply(get_Iu)
df['Ui'] = df.iid.apply(get_Ui)
df['err'] = abs(df.est - df.rui)
best_predictions = df.sort_values(by='err')[:10]
worst_predictions = df.sort_values(by='err')[-10:]

# %%
df
# Out:
#        uid   iid  rui       est                                    details  \
# 0      458   483  5.0  4.546551  {'actual_k': 40, 'was_impossible': False}
# 1      312   185  5.0  4.231579  {'actual_k': 40, 'was_impossible': False}
# 2      250   179  4.0  4.123165  {'actual_k': 40, 'was_impossible': False}
# 3      825   276  1.0  3.685472  {'actual_k': 40, 'was_impossible': False}
# 4      130   315  4.0  4.166190  {'actual_k': 40, 'was_impossible': False}
# ...    ...   ...  ...       ...                                        ...
# 24995  880   177  5.0  4.037615  {'actual_k': 40, 'was_impossible': False}
# 24996  472   100  5.0  4.335637  {'actual_k': 40, 'was_impossible': False}
# 24997  109    71  4.0  4.027099  {'actual_k': 40, 'was_impossible': False}
# 24998  454    77  4.0  3.213800  {'actual_k': 40, 'was_impossible': False}
# 24999   63  1138  2.0  3.541922   {'actual_k': 3, 'was_impossible': False}
#
#         Iu   Ui       err
# 0      130  193  0.453449
# 1      162  180  0.768421
# 2       93  163  0.123165
# 3      102  221  2.685472
# 4      274  117  0.166190
# ...    ...  ...       ...
# 24995  264   88  0.962385
# 24996  191  385  0.664363
# 24997  176  170  0.027099
# 24998  177  107  0.786200
# 24999   59    3  1.541922
#
# [25000 rows x 8 columns]

# %%
best_predictions
# Out:
#        uid   iid  rui  est                                   details   Iu  Ui  \
# 2847   782  1664  4.0  4.0  {'actual_k': 1, 'was_impossible': False}  164   1
# 13071  896  1672  2.0  2.0  {'actual_k': 1, 'was_impossible': False}  270   1
# 563    655  1379  3.0  3.0  {'actual_k': 2, 'was_impossible': False}  501   2
# 23628    5   439  1.0  1.0  {'actual_k': 2, 'was_impossible': False}  136   2
# 5488   222   247  1.0  1.0  {'actual_k': 2, 'was_impossible': False}  300   2
# 24403  776   439  1.0  1.0  {'actual_k': 2, 'was_impossible': False}   81   2
# 17844  181  1354  1.0  1.0  {'actual_k': 1, 'was_impossible': False}  321   1
# 7399     5   437  1.0  1.0  {'actual_k': 4, 'was_impossible': False}  136   4
# 5790   519  1293  5.0  5.0  {'actual_k': 2, 'was_impossible': False}   32   2
# 22139  181  1162  1.0  1.0  {'actual_k': 2, 'was_impossible': False}  321   2
#
#        err
# 2847   0.0
# 13071  0.0
# 563    0.0
# 23628  0.0
# 5488   0.0
# 24403  0.0
# 17844  0.0
# 7399   0.0
# 5790   0.0
# 22139  0.0

# %%
worst_predictions
# Out:
#        uid   iid  rui       est                                    details  \
# 6742   401   127  1.0  4.314673  {'actual_k': 40, 'was_impossible': False}
# 16592  562   114  1.0  4.345554  {'actual_k': 40, 'was_impossible': False}
# 18456  405   851  1.0  4.347989   {'actual_k': 2, 'was_impossible': False}
# 20399  707   641  1.0  4.348378  {'actual_k': 24, 'was_impossible': False}
# 19766  517  1177  5.0  1.624446   {'actual_k': 4, 'was_impossible': False}
# 21638  427   263  5.0  1.609333  {'actual_k': 15, 'was_impossible': False}
# 18622  286   285  1.0  4.398816  {'actual_k': 40, 'was_impossible': False}
# 9561   681  1394  5.0  1.587868   {'actual_k': 5, 'was_impossible': False}
# 17900  472   375  5.0  1.580821  {'actual_k': 16, 'was_impossible': False}
# 13618   38   247  5.0  1.000000   {'actual_k': 2, 'was_impossible': False}
#
#         Iu   Ui       err
# 6742   113  314  3.314673
# 16592   57   54  3.345554
# 18456  544    2  3.347989
# 20399  163   24  3.348378
# 19766   29    4  3.375554
# 21638   27   15  3.390667
# 18622  220  122  3.398816
# 9561    14    5  3.412132
# 17900  191   16  3.419179
# 13618   88    2  4.000000
